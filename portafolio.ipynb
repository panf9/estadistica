# %% [markdown]
# <a href="https://colab.research.google.com/github/panf9/estadistica/blob/main/portafolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import math
from scipy.stats import norm

# %%
datos = "https://raw.githubusercontent.com/panf9/estadistica/main/datos_inf.csv"

df_datos = pd.read_csv(datos, sep=',')
df_datos.head(5) # Mostramos llas 5 primeras filas para verificar que todo esta correcto.
# Out:
#        C1      C2      C3      C4      C5      C6
# 0  80.243  61.824  66.314  63.103  67.238  69.711
# 1  66.473  80.862  84.818  74.646  69.761  78.643
# 2  70.648  75.058  84.802  70.692  79.907  64.100
# 3  74.796  68.798  76.252  82.898  81.216  68.705
# 4  71.375  67.735  63.637  78.562  84.647  62.657

# %%
df_datos[['C3', 'C4']].describe()
# Out:
#               C3         C4
# count  20.000000  20.000000
# mean   73.584400  71.697700
# std     7.494316   7.887897
# min    61.266000  60.025000
# 25%    67.295000  65.133250
# 50%    75.734500  70.287500
# 75%    78.047000  78.434500
# max    84.818000  84.286000

# %% [markdown]
# De los datos anteriores podemos notar que: \\
# $S_3 = 7.494316$ \\
# $S_4 = 7.887897$ \\
# $X_3 = 73.584400$ \\
# $X_4 = 71.697700$

# %%
math.sqrt(128.6)
# Out:
# 11.34019400186787

# %%
n_mujeres = 20
u_mujeres = 55.8
s = 11.3401
x_mujeres = 73.584400

k = (x_mujeres - u_mujeres)/(s/math.sqrt(n_mujeres))
k
# Out:
# 7.013540857496366

# %%
z = norm.ppf(1-0.1)
print(z)
# Out:
# 1.2815515655446004

# %%
(7.494316*7.494316)/(7.887897*7.887897)
# Out:
# 0.9026960470541957

# %%
norm.qf(1-0.1/2, 20-1 ,20-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-80b7e4f959ba> in <cell line: 1>()
# ----> 1 norm.qf(1-0.1/2, 20-1 ,20-1)
#
# AttributeError: 'norm_gen' object has no attribute 'qf'
